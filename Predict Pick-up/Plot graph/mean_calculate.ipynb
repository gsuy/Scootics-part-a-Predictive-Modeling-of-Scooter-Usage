# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
sns.set()
import copy

from google.colab import files
from google.colab import drive
from functools import partial
drive.mount('/content/drive')

# %% [markdown]
# #Data set

# %%
#12/09/2019 -> 26/09/2019
output_true_A = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/A/output_true_A_lv1.csv')
output_true_B = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/B/output_true_B_lv1.csv')
output_true_C = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/C/output_true_C_lv1.csv')
output_true_D = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/D/output_true_D_lv1.csv')

output_pred_A_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/A/output_pred_A_lv3.csv')
output_pred_B_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/B/output_pred_B_lv3.csv')
output_pred_C_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/C/output_pred_C_lv3.csv')
output_pred_D_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/D/output_pred_D_lv3.csv')

output_pred_A_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/A/output_pred_A_lv2.csv')
output_pred_B_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/B/output_pred_B_lv2.csv')
output_pred_C_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/C/output_pred_C_lv2.csv')
output_pred_D_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/D/output_pred_D_lv2.csv')

output_pred_A_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/A/output_pred_A_lv1.csv')
output_pred_B_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/B/output_pred_B_lv1.csv')
output_pred_C_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/C/output_pred_C_lv1.csv')
output_pred_D_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/G/D/output_pred_D_lv1.csv')

# %%
output_pred_B_2.equals(output_pred_C_2)

# %%
output_pred_all_A_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/1/output_pred_all_A_lv1.csv')
output_pred_all_B_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/1/output_pred_all_B_lv1.csv')
output_pred_all_C_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/1/output_pred_all_C_lv1.csv')
output_pred_all_D_1 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/1/output_pred_all_D_lv1.csv')

output_pred_all_A_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/2/output_pred_all_A_lv2.csv')
output_pred_all_B_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/2/output_pred_all_B_lv2.csv')
output_pred_all_C_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/2/output_pred_all_C_lv2.csv')
output_pred_all_D_2 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/2/output_pred_all_D_lv2.csv')

output_pred_all_A_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/3/output_pred_all_A_lv3.csv')
output_pred_all_B_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/3/output_pred_all_B_lv3.csv')
output_pred_all_C_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/3/output_pred_all_C_lv3.csv')
output_pred_all_D_3 = pd.read_csv(r'/content/drive/My Drive/Colab Notebooks/Dataset/output_prediction/NG/3/output_pred_all_D_lv3.csv')

# %%
true = output_true_A.append([output_true_B,output_true_C,output_true_D])

pred_g_1 = output_pred_A_1.append([output_pred_B_1,output_pred_C_1,output_pred_D_1])
pred_g_2 = output_pred_A_2.append([output_pred_B_2,output_pred_C_2,output_pred_D_2])
pred_g_3 = output_pred_A_3.append([output_pred_B_3,output_pred_C_3,output_pred_D_3])

pred_all_1 = output_pred_all_A_1.append([output_pred_all_B_1,output_pred_all_C_1,output_pred_all_D_1])
pred_all_2 = output_pred_all_A_2.append([output_pred_all_B_2,output_pred_all_C_2,output_pred_all_D_2])
pred_all_3 = output_pred_all_A_3.append([output_pred_all_B_3,output_pred_all_C_3,output_pred_all_D_3])

# %%
pred_g_1.equals(pred_g_2)

# %% [markdown]
# #Estimate Calculate

# %%
estimates = true.copy()
estimates = estimates.iloc[0:0]

estimateA3 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateB3 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateC3 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateD3 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])

estimateA2 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateB2 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateC2 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateD2 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])

estimateA1 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateB1 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateC1 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimateD1 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])

estimate1 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimate2 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])
estimate3 = estimates.drop(columns=['start_date', 'start_day','grid_ID'])

for i in range(24) :
  #true - predict

  estimate1[str(i)] = true[str(i)] - pred_all_1[str(i)]
  estimate2[str(i)] = true[str(i)] - pred_all_2[str(i)]
  estimate3[str(i)] = true[str(i)] - pred_all_3[str(i)]


  estimateA3[str(i)] = output_true_A[str(i)] - output_pred_A_3[str(i)]
  estimateB3[str(i)] = output_true_B[str(i)] - output_pred_B_3[str(i)]
  estimateC3[str(i)] = output_true_C[str(i)] - output_pred_C_3[str(i)]
  estimateD3[str(i)] = output_true_D[str(i)] - output_pred_D_3[str(i)]

  estimateA2[str(i)] = output_true_A[str(i)] - output_pred_A_2[str(i)]
  estimateB2[str(i)] = output_true_B[str(i)] - output_pred_B_2[str(i)]
  estimateC2[str(i)] = output_true_C[str(i)] - output_pred_C_2[str(i)]
  estimateD2[str(i)] = output_true_D[str(i)] - output_pred_D_2[str(i)]

  estimateA1[str(i)] = output_true_A[str(i)] - output_pred_A_1[str(i)]
  estimateB1[str(i)] = output_true_B[str(i)] - output_pred_B_1[str(i)]
  estimateC1[str(i)] = output_true_C[str(i)] - output_pred_C_1[str(i)]
  estimateD1[str(i)] = output_true_D[str(i)] - output_pred_D_1[str(i)]

# %%
estimate_1 = pd.DataFrame()
estimate_2 = pd.DataFrame()
estimate_3 = pd.DataFrame()

#over_estimate / true - predict = +
#under_estimate / true - predict = -
#if true - predict = 0 -> add 0 both
#---------------------------total-------------------------------------------#
over_estimate_3 = estimate3.where(estimate3 >= 0 )
under_estimate_3 = estimate3.where(estimate3 <= 0)
estimate_3['over_estimate'] = over_estimate_3.mean(axis = 0, skipna = True)
estimate_3['under_estimate'] = under_estimate_3.mean(axis = 0, skipna = True)
estimate_3['over_estimate_std'] = over_estimate_3.std(axis = 0, skipna = True)
estimate_3['under_estimate_std'] = under_estimate_3.std(axis = 0, skipna = True)
estimate_3 = estimate_3.fillna(0)

over_estimate_2 = estimate2.where(estimate2 >= 0 )
under_estimate_2 = estimate2.where(estimate2 <= 0)
estimate_2['over_estimate'] = over_estimate_2.mean(axis = 0, skipna = True)
estimate_2['under_estimate'] = under_estimate_2.mean(axis = 0, skipna = True)
estimate_2['over_estimate_std'] = over_estimate_2.std(axis = 0, skipna = True)
estimate_2['under_estimate_std'] = under_estimate_2.std(axis = 0, skipna = True)
estimate_2 = estimate_2.fillna(0)

over_estimate_1 = estimate1.where(estimate1 >= 0 )
under_estimate_1 = estimate1.where(estimate1 <= 0)
estimate_1['over_estimate'] = over_estimate_1.mean(axis = 0, skipna = True)
estimate_1['under_estimate'] = under_estimate_1.mean(axis = 0, skipna = True)
estimate_1['over_estimate_std'] = over_estimate_1.std(axis = 0, skipna = True)
estimate_1['under_estimate_std'] = under_estimate_1.std(axis = 0, skipna = True)
estimate_1 = estimate_1.fillna(0)

# %%
estimate_a1 = pd.DataFrame()
estimate_a2 = pd.DataFrame()
estimate_a3 = pd.DataFrame()

#over_estimate / true - predict = +
#under_estimate / true - predict = -
#if true - predict = 0 -> add 0 both
#---------------------------A-------------------------------------------#
over_estimate_a3 = estimateA3.where(estimateA3 >= 0 )
under_estimate_a3 = estimateA3.where(estimateA3 <= 0)
estimate_a3['over_estimate'] = over_estimate_a3.mean(axis = 0, skipna = True)
estimate_a3['under_estimate'] = under_estimate_a3.mean(axis = 0, skipna = True)
estimate_a3['over_estimate_std'] = over_estimate_a3.std(axis = 0, skipna = True)
estimate_a3['under_estimate_std'] = under_estimate_a3.std(axis = 0, skipna = True)
estimate_a3 = estimate_a3.fillna(0)

over_estimate_a2 = estimateA2.where(estimateA2 >= 0 )
under_estimate_a2 = estimateA2.where(estimateA2 <= 0)
estimate_a2['over_estimate'] = over_estimate_a2.mean(axis = 0, skipna = True)
estimate_a2['under_estimate'] = under_estimate_a2.mean(axis = 0, skipna = True)
estimate_a2['over_estimate_std'] = over_estimate_a2.std(axis = 0, skipna = True)
estimate_a2['under_estimate_std'] = under_estimate_a2.std(axis = 0, skipna = True)
estimate_a2 = estimate_a2.fillna(0)

over_estimate_a1 = estimateA1.where(estimateA1 >= 0 )
under_estimate_a1 = estimateA1.where(estimateA1 <= 0)
estimate_a1['over_estimate'] = over_estimate_a1.mean(axis = 0, skipna = True)
estimate_a1['under_estimate'] = under_estimate_a1.mean(axis = 0, skipna = True)
estimate_a1['over_estimate_std'] = over_estimate_a1.std(axis = 0, skipna = True)
estimate_a1['under_estimate_std'] = under_estimate_a1.std(axis = 0, skipna = True)
estimate_a1 = estimate_a1.fillna(0)

# %%
estimate_b1 = pd.DataFrame()
estimate_b2 = pd.DataFrame()
estimate_b3 = pd.DataFrame()

#over_estimate / true - predict = +
#under_estimate / true - predict = -
#if true - predict = 0 -> add 0 both
#---------------------------B-------------------------------------------#
over_estimate_b3 = estimateB3.where(estimateB3 >= 0 )
under_estimate_b3 = estimateB3.where(estimateB3 <= 0)
estimate_b3['over_estimate'] = over_estimate_b3.mean(axis = 0, skipna = True)
estimate_b3['under_estimate'] = under_estimate_b3.mean(axis = 0, skipna = True)
estimate_b3['over_estimate_std'] = over_estimate_b3.std(axis = 0, skipna = True)
estimate_b3['under_estimate_std'] = under_estimate_b3.std(axis = 0, skipna = True)
estimate_b3 = estimate_b3.fillna(0)

over_estimate_b2 = estimateB2.where(estimateB2 >= 0 )
under_estimate_b2 = estimateB2.where(estimateB2 <= 0)
estimate_b2['over_estimate'] = over_estimate_b2.mean(axis = 0, skipna = True)
estimate_b2['under_estimate'] = under_estimate_b2.mean(axis = 0, skipna = True)
estimate_b2['over_estimate_std'] = over_estimate_b2.std(axis = 0, skipna = True)
estimate_b2['under_estimate_std'] = under_estimate_b2.std(axis = 0, skipna = True)
estimate_b2 = estimate_b2.fillna(0)

over_estimate_b1 = estimateB1.where(estimateB1 >= 0 )
under_estimate_b1 = estimateB1.where(estimateB1 <= 0)
estimate_b1['over_estimate'] = over_estimate_b1.mean(axis = 0, skipna = True)
estimate_b1['under_estimate'] = under_estimate_b1.mean(axis = 0, skipna = True)
estimate_b1['over_estimate_std'] = over_estimate_b1.std(axis = 0, skipna = True)
estimate_b1['under_estimate_std'] = under_estimate_b1.std(axis = 0, skipna = True)
estimate_b1 = estimate_b1.fillna(0)

# %%
estimate_c1 = pd.DataFrame()
estimate_c2 = pd.DataFrame()
estimate_c3 = pd.DataFrame()

#over_estimate / true - predict = +
#under_estimate / true - predict = -
#if true - predict = 0 -> add 0 both
#---------------------------C-------------------------------------------#
over_estimate_c3 = estimateC3.where(estimateC3 >= 0 )
under_estimate_c3 = estimateC3.where(estimateC3 <= 0)
estimate_c3['over_estimate'] = over_estimate_c3.mean(axis = 0, skipna = True)
estimate_c3['under_estimate'] = under_estimate_c3.mean(axis = 0, skipna = True)
estimate_c3['over_estimate_std'] = over_estimate_c3.std(axis = 0, skipna = True)
estimate_c3['under_estimate_std'] = under_estimate_c3.std(axis = 0, skipna = True)
estimate_c3 = estimate_c3.fillna(0)

over_estimate_c2 = estimateC2.where(estimateC2 >= 0 )
under_estimate_c2 = estimateC2.where(estimateC2 <= 0)
estimate_c2['over_estimate'] = over_estimate_c2.mean(axis = 0, skipna = True)
estimate_c2['under_estimate'] = under_estimate_c2.mean(axis = 0, skipna = True)
estimate_c2['over_estimate_std'] = over_estimate_c2.std(axis = 0, skipna = True)
estimate_c2['under_estimate_std'] = under_estimate_c2.std(axis = 0, skipna = True)
estimate_c2 = estimate_c2.fillna(0)

over_estimate_c1 = estimateC1.where(estimateC1 >= 0 )
under_estimate_c1 = estimateC1.where(estimateC1 <= 0)
estimate_c1['over_estimate'] = over_estimate_c1.mean(axis = 0, skipna = True)
estimate_c1['under_estimate'] = under_estimate_c1.mean(axis = 0, skipna = True)
estimate_c1['over_estimate_std'] = over_estimate_c1.std(axis = 0, skipna = True)
estimate_c1['under_estimate_std'] = under_estimate_c1.std(axis = 0, skipna = True)
estimate_c1 = estimate_c1.fillna(0)

# %%
estimate_d1 = pd.DataFrame()
estimate_d2 = pd.DataFrame()
estimate_d3 = pd.DataFrame()

#over_estimate / true - predict = +
#under_estimate / true - predict = -
#if true - predict = 0 -> add 0 both
#---------------------------D-------------------------------------------#
over_estimate_d3 = estimateD3.where(estimateD3 >= 0 )
under_estimate_d3 = estimateD3.where(estimateD3 <= 0)
estimate_d3['over_estimate'] = over_estimate_d3.mean(axis = 0, skipna = True)
estimate_d3['under_estimate'] = under_estimate_d3.mean(axis = 0, skipna = True)
estimate_d3['over_estimate_std'] = over_estimate_d3.std(axis = 0, skipna = True)
estimate_d3['under_estimate_std'] = under_estimate_d3.std(axis = 0, skipna = True)
estimate_d3 = estimate_b3.fillna(0)

over_estimate_d2 = estimateD2.where(estimateD2 >= 0 )
under_estimate_d2 = estimateD2.where(estimateD2 <= 0)
estimate_d2['over_estimate'] = over_estimate_d2.mean(axis = 0, skipna = True)
estimate_d2['under_estimate'] = under_estimate_d2.mean(axis = 0, skipna = True)
estimate_d2['over_estimate_std'] = over_estimate_d2.std(axis = 0, skipna = True)
estimate_d2['under_estimate_std'] = under_estimate_d2.std(axis = 0, skipna = True)
estimate_d2 = estimate_d2.fillna(0)

over_estimate_d1 = estimateD1.where(estimateD1 >= 0 )
under_estimate_d1 = estimateD1.where(estimateD1 <= 0)
estimate_d1['over_estimate'] = over_estimate_d1.mean(axis = 0, skipna = True)
estimate_d1['under_estimate'] = under_estimate_d1.mean(axis = 0, skipna = True)
estimate_d1['over_estimate_std'] = over_estimate_d1.std(axis = 0, skipna = True)
estimate_d1['under_estimate_std'] = under_estimate_d1.std(axis = 0, skipna = True)
estimate_d1 = estimate_d1.fillna(0)

# %% [markdown]
# #Plot Estimate

# %%
fig, axs = plt.subplots(2, 2,figsize=(18,10))

labels = ["over_est", "under_est"]
fig.suptitle(' Grouping-based training Model1',fontsize=15,verticalalignment='bottom')

axs[0, 0].plot(estimate_a1.index,estimate_a1.over_estimate,label=labels[0])
axs[0, 0].plot(estimate_a1.index,estimate_a1.under_estimate,label=labels[1])
axs[0, 0].set_title('Group A')
axs[0, 0].legend(loc="upper left")

axs[0, 1].plot(estimate_b1.index,estimate_b1.over_estimate,label=labels[0])
axs[0, 1].plot(estimate_b1.index,estimate_b1.under_estimate,label=labels[1])
axs[0, 1].set_title('Group B')
axs[0, 1].legend(loc="upper left")

axs[1, 0].plot(estimate_c1.index,estimate_c1.over_estimate,label=labels[0])
axs[1, 0].plot(estimate_c1.index,estimate_c1.under_estimate,label=labels[1])
axs[1, 0].set_title('Group C')
axs[1, 0].legend(loc="upper left")

axs[1, 1].plot(estimate_d1.index,estimate_d1.over_estimate,label=labels[0])
axs[1, 1].plot(estimate_d1.index,estimate_d1.under_estimate,label=labels[1])
axs[1, 1].set_title('Group D')
axs[1, 1].legend(loc="upper left")


for ax in axs.flat:
    ax.set(xlabel='hour', ylabel='average estimate')

plt.tight_layout()

plt.show();

# %%
fig, axs = plt.subplots(2, 2,figsize=(18,10))

labels = ["over_est", "under_est"]
fig.suptitle('Grouping-based training Model2',fontsize=15,verticalalignment='bottom')

axs[0, 0].plot(estimate_a2.index,estimate_a2.over_estimate,label=labels[0])
axs[0, 0].plot(estimate_a2.index,estimate_a2.under_estimate,label=labels[1])
axs[0, 0].set_title('Group A')
axs[0, 0].legend(loc="upper left")

axs[0, 1].plot(estimate_b2.index,estimate_b2.over_estimate,label=labels[0])
axs[0, 1].plot(estimate_b2.index,estimate_b2.under_estimate,label=labels[1])
axs[0, 1].set_title('Group B')
axs[0, 1].legend(loc="upper left")

axs[1, 0].plot(estimate_c2.index,estimate_c2.over_estimate,label=labels[0])
axs[1, 0].plot(estimate_c2.index,estimate_c2.under_estimate,label=labels[1])
axs[1, 0].set_title('Group C')
axs[1, 0].legend(loc="upper left")

axs[1, 1].plot(estimate_d2.index,estimate_d2.over_estimate,label=labels[0])
axs[1, 1].plot(estimate_d2.index,estimate_d2.under_estimate,label=labels[1])
axs[1, 1].set_title('Group D')
axs[1, 1].legend(loc="upper left")


for ax in axs.flat:
    ax.set(xlabel='hour', ylabel='average estimate')

plt.tight_layout()

plt.show();

# %%
fig, axs = plt.subplots(2, 2,figsize=(18,10))

labels = ["over_est", "under_est"]
fig.suptitle('Grouping-based training Model3',fontsize=15,verticalalignment='bottom')

axs[0, 0].plot(estimate_a3.index,estimate_a3.over_estimate,label=labels[0])
axs[0, 0].plot(estimate_a3.index,estimate_a3.under_estimate,label=labels[1])
axs[0, 0].set_title('Group A')
axs[0, 0].legend(loc="upper left")

axs[0, 1].plot(estimate_b3.index,estimate_b3.over_estimate,label=labels[0])
axs[0, 1].plot(estimate_b3.index,estimate_b3.under_estimate,label=labels[1])
axs[0, 1].set_title('Group B')
axs[0, 1].legend(loc="upper left")

axs[1, 0].plot(estimate_c3.index,estimate_c3.over_estimate,label=labels[0])
axs[1, 0].plot(estimate_c3.index,estimate_c3.under_estimate,label=labels[1])
axs[1, 0].set_title('Group C')
axs[1, 0].legend(loc="upper left")

axs[1, 1].plot(estimate_d2.index,estimate_d2.over_estimate,label=labels[0])
axs[1, 1].plot(estimate_d2.index,estimate_d2.under_estimate,label=labels[1])
axs[1, 1].set_title('Group D')
axs[1, 1].legend(loc="upper left")


for ax in axs.flat:
    ax.set(xlabel='hour', ylabel='average estimate')

plt.tight_layout()

plt.show();

# %%
fig, axs = plt.subplots(2, 2,figsize=(18,10))

labels = ["over_est", "under_est"]
fig.suptitle('Grouping-based training Overall',fontsize=15,verticalalignment='bottom')

axs[0, 0].plot(estimate_1.index,estimate_1.over_estimate,label=labels[0])
axs[0, 0].plot(estimate_1.index,estimate_1.under_estimate,label=labels[1])
axs[0, 0].set_title('Model 1')
axs[0, 0].legend(loc="upper left")

axs[0, 1].plot(estimate_2.index,estimate_2.over_estimate,label=labels[0])
axs[0, 1].plot(estimate_2.index,estimate_2.under_estimate,label=labels[1])
axs[0, 1].set_title('Model 2')
axs[0, 1].legend(loc="upper left")

axs[1, 0].plot(estimate_3.index,estimate_3.over_estimate,label=labels[0])
axs[1, 0].plot(estimate_3.index,estimate_3.under_estimate,label=labels[1])
axs[1, 0].set_title('Model 3')
axs[1, 0].legend(loc="upper left")


for ax in axs.flat:
    ax.set(xlabel='hour', ylabel='average estimate')

plt.tight_layout()

plt.show();

# %%
fig, axs = plt.subplots(figsize=(18,10))

labels = ["over_est1", "under_est1","over_est2", "under_est2","over_est3", "under_est3"]

fig.suptitle('Grouping-based training Overall',fontsize=15,verticalalignment='bottom')

axs.plot(estimate_1.index,estimate_1.over_estimate,label=labels[0])
axs.plot(estimate_1.index,estimate_1.under_estimate,label=labels[1])


axs.plot(estimate_2.index,estimate_2.over_estimate,label=labels[2])
axs.plot(estimate_2.index,estimate_2.under_estimate,label=labels[3])


axs.plot(estimate_3.index,estimate_3.over_estimate,label=labels[4])
axs.plot(estimate_3.index,estimate_3.under_estimate,label=labels[5])


axs.legend(loc="upper left")
axs.set(xlabel='hour', ylabel='average estimate')

plt.tight_layout()

plt.show();

# %% [markdown]
# #AvgEstimate

# %%
print('a = ', estimate_a1.over_estimate.mean(),estimate_a1.under_estimate.mean())
print('b = ', estimate_b1.over_estimate.mean(),estimate_b1.under_estimate.mean())
print('c = ', estimate_c1.over_estimate.mean(),estimate_c1.under_estimate.mean())
print('d = ', estimate_d1.over_estimate.mean(),estimate_d1.under_estimate.mean())

# %%
print('1 = ', estimate_1.over_estimate.mean(),estimate_1.under_estimate.mean())
print('2 = ', estimate_2.over_estimate.mean(),estimate_2.under_estimate.mean())
print('3 = ', estimate_3.over_estimate.mean(),estimate_3.under_estimate.mean())

# %% [markdown]
# #ZeroAcc

# %%
output_true_a = output_true_A.copy()
output_true_b = output_true_B.copy()
output_true_c = output_true_C.copy()
output_true_d = output_true_D.copy()

output_true_1 = true.copy()


output_true_a = output_true_a.drop(columns=['start_date', 'start_day','grid_ID'])
output_true_b = output_true_b.drop(columns=['start_date', 'start_day','grid_ID'])
output_true_c = output_true_c.drop(columns=['start_date', 'start_day','grid_ID'])
output_true_d = output_true_d.drop(columns=['start_date', 'start_day','grid_ID'])

output_true_all = output_true_1.drop(columns=['start_date', 'start_day','grid_ID'])


output_pred_a = output_pred_A_3.copy()
output_pred_b = output_pred_B_3.copy()
output_pred_c = output_pred_C_3.copy()
output_pred_d = output_pred_D_3.copy()

output_pred_1 = pred_g_1.copy()
output_pred_2 = pred_g_2.copy()
output_pred_3 = pred_g_3.copy()

output_pred_a = output_pred_a.drop(columns=['start_date', 'start_day','grid_ID'])
output_pred_b = output_pred_b.drop(columns=['start_date', 'start_day','grid_ID'])
output_pred_c = output_pred_c.drop(columns=['start_date', 'start_day','grid_ID'])
output_pred_d = output_pred_d.drop(columns=['start_date', 'start_day','grid_ID'])

output_pred_1 = output_pred_1.drop(columns=['start_date', 'start_day','grid_ID'])
output_pred_2 = output_pred_2.drop(columns=['start_date', 'start_day','grid_ID'])
output_pred_3 = output_pred_3.drop(columns=['start_date', 'start_day','grid_ID'])

zeror_a = pd.DataFrame()
zeror_b = pd.DataFrame()
zeror_c = pd.DataFrame()
zeror_d = pd.DataFrame()
zeror_ = pd.DataFrame()

zeror_alll = pd.DataFrame()
zeror_all = pd.DataFrame()


for i in range(24) :
  zeror_a[str(i)] = np.where((output_true_a[str(i)] == 0)
                     ,0, np.nan)
  zeror_b[str(i)] = np.where((output_true_b[str(i)] == 0)
                     ,0, np.nan)
  zeror_c[str(i)] = np.where((output_true_c[str(i)] == 0)
                     ,0, np.nan)
  zeror_d[str(i)] = np.where((output_true_d[str(i)] == 0)
                     ,0, np.nan)
  
  zeror_alll[str(i)] = np.where((output_true_all[str(i)] == 0)
                     ,0, np.nan)  

  
zeror_['A'] = zeror_a.count()
zeror_['B'] = zeror_b.count()
zeror_['C'] = zeror_c.count()
zeror_['D'] = zeror_d.count()
zeror_all['total'] = zeror_alll.count()

# %%
zeror_all

# %%
zero_a = pd.DataFrame()
zero_b = pd.DataFrame()
zero_c = pd.DataFrame()
zero_d = pd.DataFrame()
zero_ = pd.DataFrame()
zero_all = pd.DataFrame()
zero_1 = pd.DataFrame()
zero_2 = pd.DataFrame()
zero_3 = pd.DataFrame()

for i in range(24) :
  zero_a[str(i)] = np.where((output_true_a[str(i)] == output_pred_a[str(i)]) & (output_pred_a[str(i)] == 0)
                     ,0, np.nan)
  zero_b[str(i)] = np.where((output_true_b[str(i)] == output_pred_b[str(i)]) & (output_pred_b[str(i)] == 0)
                     ,0, np.nan)
  zero_c[str(i)] = np.where((output_true_c[str(i)] == output_pred_c[str(i)]) & (output_pred_c[str(i)] == 0)
                     ,0, np.nan)
  zero_d[str(i)] = np.where((output_true_d[str(i)] == output_pred_d[str(i)]) & (output_pred_d[str(i)] == 0)
                     ,0, np.nan)
  
  zero_1[str(i)] = np.where((output_true_all[str(i)] == output_pred_1[str(i)]) & (output_pred_1[str(i)] == 0)
                     ,0, np.nan)
  zero_2[str(i)] = np.where((output_true_all[str(i)] == output_pred_2[str(i)]) & (output_pred_2[str(i)] == 0)
                     ,0, np.nan)
  zero_3[str(i)] = np.where((output_true_all[str(i)] == output_pred_3[str(i)]) & (output_pred_3[str(i)] == 0)
                     ,0, np.nan)
  
zero_['A'] = zero_a.count()
zero_['B'] = zero_b.count()
zero_['C'] = zero_c.count()
zero_['D'] = zero_d.count()

zero_all['m1'] = zero_1.count()
zero_all['m2'] = zero_2.count()
zero_all['m3'] = zero_3.count()

# %%
zero_all

# %%
zero_acc = pd.DataFrame()
zero_acc_all = pd.DataFrame()

zero_acc['A'] = (zero_['A']*100) / zeror_['A']
zero_acc['B'] = (zero_['B']*100) / zeror_['B']
zero_acc['C'] = (zero_['C']*100) / zeror_['C']
zero_acc['D'] = (zero_['D']*100) / zeror_['D']
zero_acc = zero_acc.fillna(0)

zero_acc_all['m1'] = (zero_all['m1']*100) / zeror_all['total']
zero_acc_all['m2'] = (zero_all['m2']*100) / zeror_all['total']
zero_acc_all['m3'] = (zero_all['m3']*100) / zeror_all['total']
zero_acc_all = zero_acc_all.fillna(0)

# %%
print('a =',zero_acc.A.mean())
print('b =',zero_acc.B.mean())
print('c =',zero_acc.C.mean())
print('d =',zero_acc.D.mean())

# %%
print('1 =',zero_acc_all.m1.mean())
print('2 =',zero_acc_all.m2.mean())
print('3 =',zero_acc_all.m3.mean())

# %%
fig, axs = plt.subplots(figsize=(12,7))

labels = ["Zero_acc_1","Zero_acc_2","Zero_acc_3"]
# fig.suptitle('Zero Accuracy',fontsize=15,verticalalignment='bottom')

axs.plot(zero_acc_all.index,zero_acc_all.m1,label=labels[0])
axs.plot(zero_acc_all.index,zero_acc_all.m2,label=labels[1])
axs.plot(zero_acc_all.index,zero_acc_all.m3,label=labels[2])

axs.set_title('Overall results Zero Accuracy')
axs.legend(loc="upper right")

axs.set(xlabel='hour', ylabel='Accuracy(%)')

# for ax in axs.flat:
#     ax.set(xlabel='hour', ylabel='Accuracy(%)')

plt.tight_layout()

plt.show();

# %%
fig, axs = plt.subplots(figsize=(12,7))

labels = ["Zero_acc_A","Zero_acc_B","Zero_acc_C","Zero_acc_D"]
# fig.suptitle('Zero Accuracy',fontsize=15,verticalalignment='bottom')

axs.plot(zero_acc.index,zero_acc.A,label=labels[0])
axs.plot(zero_acc.index,zero_acc.B,label=labels[1])
axs.plot(zero_acc.index,zero_acc.C,label=labels[2])
axs.plot(zero_acc.index,zero_acc.D,label=labels[3])

axs.set_title('Overall results Zero Accuracy model 3')
axs.legend(loc="upper right")

axs.set(xlabel='hour', ylabel='Accuracy(%)')

# for ax in axs.flat:
#     ax.set(xlabel='hour', ylabel='Accuracy(%)')

plt.tight_layout()

plt.show();
